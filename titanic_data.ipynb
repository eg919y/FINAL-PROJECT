# %%
# %pylab inline
import unicodecsv
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

first_titanic_df = pd.read_csv("titanic_data.csv")
second_titanic_df = pd.read_csv("gender_submission.csv")
titanic_data_df = pd.merge(first_titanic_df, second_titanic_df, how = 'left', on = ['Survived'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fourth_titanic_df = pd.read_csv("test.csv")
#titanic_df = pd.merge(titanic_data_df, fourth_titanic_df, how = 'left', on = [['PassengerId', 'Pclass', 'Age', 'Embarked']])
print fourth_titanic_df.columns.values
# Out:
# ['PassengerId' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch' 'Ticket' 'Fare'
#  'Cabin' 'Embarked']

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    864.000000    0.371493    2.308642   29.699118    0.523008
# std     257.353842    0.483475    0.836071   14.526497    1.102743
# min     419.000000    0.000000    1.000000    0.420000    0.000000
# 25%     641.500000    0.000000    2.000000   20.125000    0.000000
# 50%     864.000000    0.000000    3.000000   28.000000    0.000000
# 75%    1086.500000    1.000000    3.000000   38.000000    1.000000
# max    1309.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df = pd.read_csv("titanic_df.csv")
third_titanic_df = pd.read_csv("test.csv")
result = titanic_df.combine_first(third_titanic_df)

# %%
titanic_df.update(third_titanic_df)

# %%
titanic_df.describe()
# Out:
#        PassengerId_x       Survived         Pclass            Age  \
# count  198018.000000  198018.000000  198018.000000  156864.000000
# mean      446.321244       0.262522       2.377647      29.992346
# std       258.224113       0.440006       0.812301      14.423536
# min         1.000000       0.000000       1.000000       0.170000
# 25%       220.000000       0.000000       2.000000      21.000000
# 50%       449.000000       0.000000       3.000000      28.000000
# 75%       671.000000       1.000000       3.000000      39.000000
# max       891.000000       1.000000       3.000000      80.000000
#
#                SibSp          Parch           Fare  PassengerId_y
# count  198018.000000  198018.000000  198018.000000  198018.000000
# mean        0.532320       0.366017      29.075448    1101.089583
# std         1.164419       0.812393      45.006159     120.290467
# min         0.000000       0.000000       0.000000     892.000000
# ...

# %%
titanic_df["Count"] = 1
gender_count_df = titanic_df.groupby("Sex").sum()[["Count","Survived"]] 

gender_count_df
# Out:
#          Count  Survived
# Sex
# female   57114     35416
# male    140904     16568

# %%
gender_survived_df = titanic_df.groupby("Sex").sum()[["Survived"]] 

gender_survived_df
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
titanic_df["Count"] = 1
embarked_count_df = titanic_df.groupby("Embarked").sum()[["Count"]] 

embarked_count_df
# Out:
#           Count
# Embarked
# C           168
# Q            77
# S           644

# %%
embarked_survived_df = titanic_df.groupby("Embarked").sum()[["Survived"]] 
embarked_survived_df
# Out:
#           Survived
# Embarked
# C               93
# Q               30
# S              217

# %%
titanic_df["Count"] =1
price_paid_df = titanic_df.groupby("Fare").sum()[["Count", "Survived"]]
price_paid_df
# Out:
#           Count  Survived
# Fare
# 0.0000       15         1
# 4.0125        1         0
# 5.0000        1         0
# 6.2375        1         0
# 6.4375        1         0
# 6.4500        1         0
# 6.4958        2         0
# 6.7500        2         0
# 6.8583        1         0
# 6.9500        1         0
# 6.9750        2         1
# 7.0458        1         0
# 7.0500        7         0
# 7.0542        2         0
# 7.1250        4         0
# 7.1417        1         1
# 7.2250       12         3
# 7.2292       15         4
# 7.2500       13         1
# 7.3125        1         0
# 7.4958        3         1
# 7.5208        1         0
# 7.5500        4         1
# 7.6292        1         0
# 7.6500        4         1
# 7.7250        1         0
# 7.7292        1         0
# 7.7333        4         2
# 7.7375        2         1
# 7.7417        1         0
# ...         ...       ...
# 80.0000       2         2
# 81.8583       1         1
# 82.1708       2         1
# ...

# %%
sns.swarmplot(x = "PassengerId", y = "Fare", data = titanic_df)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
titanic_df["Count"] =1
class_gender_survived_df = titanic_df.groupby(["Pclass","Sex",]).sum()[["Count", "Survived"]]
class_gender_survived_df
# Out:
#                Count  Survived
# Pclass Sex
# 1      female     94        91
#        male      122        45
# 2      female     76        70
#        male      108        17
# 3      female    144        72
#        male      347        47

# %%
class_gender_survived_df.head()
# Out:
#                Count  Survived
# Pclass Sex
# 1      female     94        91
#        male      122        45
# 2      female     76        70
#        male      108        17
# 3      female    144        72

# %%
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=titanic_df);

# %%
embarked_gender_survived_df = titanic_df.groupby(["Embarked","Sex",]).sum()[["Survived"]]
embarked_gender_survived_df
# Out:
#                  Survived
# Embarked Sex
# C        female        64
#          male          29
# Q        female        27
#          male           3
# S        female       140
#          male          77

# %%
Age_gender_survived_df = titanic_df.groupby(["Age"]).count()[["Survived"]]
Age_gender_survived_df
# Out:
#        Survived
# Age
# 0.42          1
# 0.67          1
# 0.75          2
# 0.83          2
# 0.92          1
# 1.00          7
# 2.00         10
# 3.00          6
# 4.00         10
# 5.00          4
# 6.00          3
# 7.00          3
# 8.00          4
# 9.00          8
# 10.00         2
# 11.00         4
# 12.00         1
# 13.00         2
# 14.00         6
# 14.50         1
# 15.00         5
# 16.00        17
# 17.00        13
# 18.00        26
# 19.00        25
# 20.00        15
# 20.50         1
# 21.00        24
# 22.00        27
# 23.00        15
# ...         ...
# 44.00         9
# 45.00        12
# 45.50         2
# 46.00         3
# 47.00         9
# 48.00         9
# 49.00         6
# 50.00        10
# 51.00         7
# 52.00         6
# 53.00         1
# 54.00         8
# 55.00         2
# 55.50         1
# 56.00         4
# 57.00         2
# 58.00         5
# 59.00         2
# 60.00         4
# 61.00         3
# 62.00         4
# 63.00         2
# 64.00         2
# ...

# %%
sns.swarmplot(x="Age", y="Sex", hue="Survived", data=titanic_df);

# %%
titanic_df["Count"] =1
class_fare_df = titanic_df.groupby(["Pclass"]).sum()[["Count", "Fare"]]
class_fare_df
# Out:
#         Count        Fare
# Pclass
# 1         216  18177.4125
# 2         184   3801.8417
# 3         491   6714.6951

# %%
titanic_df["Count"] =1
survived_class_df = titanic_df.groupby(["Pclass"]).sum()[["Count", "Survived"]]
survived_class_df
# Out:
#         Count  Survived
# Pclass
# 1         216       136
# 2         184        87
# 3         491       119

# %%
titanic_df["Count"] =891
sns.barplot(x="Count", y="Pclass", hue="Survived", data=titanic_df);

# %%
sns.swarmplot(x="Pclass", y="PassengerId", data=titanic_df);
